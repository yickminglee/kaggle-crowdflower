# %%
import cfg
import pandas as pd
import numpy as np
import scipy.sparse as sp
import re
import pickle
#import cPickle as pickle

from bs4 import BeautifulSoup
from nltk.stem.porter import *
from nltk.tokenize import TreebankWordTokenizer
from nltk.stem import wordnet

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics import pairwise_distances

#from tsne import bh_sne     # use sklearn.manifold.TSNE(method='barnes_hut') instead
from sklearn.manifold import TSNE
#from gensim.models import Word2Vec
from gensim.models import KeyedVectors

import logging

# %%
logging.basicConfig(format='[%(asctime)s] %(message)s', level=logging.INFO)
logging.info("Feature extractor (Mikhail's part)")
logging.info('** see cfg.py for path settings **')
# Out:
# [2021-02-04 20:40:14,106] Feature extractor (Mikhail's part)
# [2021-02-04 20:40:14,138] ** see cfg.py for path settings **

# %% [markdown]
# # load data

# %% [raw]
# #load data
# logging.info('Reading data')
# train_df = pd.read_csv(cfg.path_train, encoding='utf-8').fillna('')
# test_df  = pd.read_csv(cfg.path_test, encoding='utf-8').fillna('')

# %% [markdown]
# #  Lemmatizing part

# %%
# download data before lemmatizing and tokenizing
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ming.lee\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
logging.info('Lemmatizing')
toker = TreebankWordTokenizer()
lemmer = wordnet.WordNetLemmatizer()
# Out:
# [2021-02-04 20:41:22,816] Lemmatizing

# %%
def text_preprocessor(x):
    '''
    Get one string and clean\lemm it
    '''
    tmp = str(x)
    tmp = tmp.lower().replace('blu-ray', 'bluray').replace('wi-fi', 'wifi')
    x_cleaned = tmp.replace('/', ' ').replace('-', ' ').replace('"', '')
    tokens = toker.tokenize(x_cleaned)
    return " ".join([lemmer.lemmatize(z) for z in tokens])

# %%
# lemm description
train_df['desc_stem']  = train_df['product_description'].apply(text_preprocessor)
test_df[ 'desc_stem']  =  test_df['product_description'].apply(text_preprocessor)
# lemm title
train_df['title_stem'] = train_df['product_title'].apply(text_preprocessor)
test_df[ 'title_stem'] =  test_df['product_title'].apply(text_preprocessor)
# lemm query
train_df['query_stem'] = train_df['query'].apply(text_preprocessor)
test_df[ 'query_stem'] =  test_df['query'].apply(text_preprocessor)

# %%
train_df.sample(10)
# Out:
#          id                    query  \
# 2189   6998   leather mens briefcase
# 5023  16176                  blender
# 7042  22754         hair accessories
# 9534  30640       pittsburgh pirates
# 2504   7971       three wheeled bike
# 1313   4245     queen comforter sets
# 6952  22455     baseball photo frame
# 4038  13052          chocolate molds
# 5370  17292         assassinss creed
# 9135  29385  ps3 wireless controller
#
#                                           product_title  \
# 2189           McKlein Ladies Leather Briefcase - Black
# 5023  Vitamix Certified Reconditioned Program Blende...
# 7042   Kate Marie 'Ada' Rhinestone Crown Tiara Hair Pin
# 9534             Pittsburgh Pirates Girls 3pk Body Suit
# 2504  Sta-Tru 27 x 1-1/4 Bolt-on Alloy Flat ted Axle...
# 1313                          Ara 8 Piece Comforter Set
# 6952                        Baseball Wood Picture Frame
# 4038  Freshware Brown 15-cavity Spiral Cone Chocolat...
# 5370           Assassins Creed 4 (Xbox 360) - Pre-Owned
# 9135            Mad Catz Wireless Controller, Red (PS3)
#
#                                     product_description  median_relevance  \
# 2189  Protect and transport your laptop in this styl...                 3
# 5023  details\nThe Keurig Cappuccino Maker - R500 Ri...                 4
# 7042  This sparkling Rhinestone Crown Tiara Hair Pin...                 4
# 9534                                                                    3
# 2504  27" x 1 1/4" wheels assembled in the USA. Fron...                 1
# 1313  The Ara 8 Piece Comforter Set will make your b...                 4
# 6952  Personalized Baseball Frame - Personalized Spo...                 3
# 4038  The spiral cone shape of this 100-percent FDA ...                 4
# 5370  It is 1715. Pirates rule the Caribbean and hav...                 3
# 9135  The Mad Catz Wireless Controller features mult...                 4
#
#       relevance_variance                                          desc_stem  \
# 2189               0.894  protect and transport your laptop in this styl...
# 5023               0.000  detail the keurig cappuccino maker r500 rivo s...
# 7042               0.000  this sparkling rhinestone crown tiara hair pin...
# 9534               0.471
# 2504               0.000  27 x 1 1 4 wheel assembled in the usa. front s...
# 1313               0.943  the ara 8 piece comforter set will make your b...
# 6952               0.471  personalized baseball frame personalized sport...
# 4038               0.000  the spiral cone shape of this 100 percent fda ...
# 5370               0.471  it is 1715. pirate rule the caribbean and have...
# 9135               0.000  the mad catz wireless controller feature multi...
#
#                                              title_stem  \
# 2189               mcklein lady leather briefcase black
# 5023  vitamix certified reconditioned program blende...
# 7042  kate marie 'ada ' rhinestone crown tiara hair pin
# 9534               pittsburgh pirate girl 3pk body suit
# 2504  sta tru 27 x 1 1 4 bolt on alloy flat ted axle...
# 1313                          ara 8 piece comforter set
# 6952                        baseball wood picture frame
# 4038  freshware brown 15 cavity spiral cone chocolat...
# 5370            assassin creed 4 ( xbox 360 ) pre owned
# 9135         mad catz wireless controller , red ( ps3 )
#
#                    query_stem
# 2189    leather men briefcase
# 5023                  blender
# 7042           hair accessory
# 9534        pittsburgh pirate
# 2504       three wheeled bike
# 1313      queen comforter set
# 6952     baseball photo frame
# 4038           chocolate mold
# 5370           assassin creed
# 9135  ps3 wireless controller

# %% [markdown]
# # Similarities

# %%
def calc_cosine_dist(text_a ,text_b, vect):
    """
    find cosine distance between TF-IDF representation
    """
    return pairwise_distances(vect.transform([text_a]), vect.transform([text_b]), metric='cosine')[0][0]

def calc_set_intersection(text_a, text_b):
    """
    find ratio of matching words
    """
    a = set(text_a.split())
    b = set(text_b.split())
    return len(a.intersection(b)) *1.0 / len(a)

# %%
# vectorizers for similarities
logging.info('\t fit vectorizers')
tfv_orig = TfidfVectorizer(ngram_range=(1,2), min_df=2)
tfv_stem = TfidfVectorizer(ngram_range=(1,2), min_df=2)
tfv_desc = TfidfVectorizer(ngram_range=(1,2), min_df=2)
tfv_orig.fit(
    list(train_df['query'].values) + 
    list(test_df['query'].values) + 
    list(train_df['product_title'].values) + 
    list(test_df['product_title'].values)
) 
tfv_stem.fit(
    list(train_df['query_stem'].values) + 
    list(test_df['query_stem'].values) + 
    list(train_df['title_stem'].values) + 
    list(test_df['title_stem'].values)
) 
tfv_desc.fit(
    list(train_df['query_stem'].values) + 
    list(test_df['query_stem'].values) + 
    list(train_df['desc_stem'].values) + 
    list(test_df['desc_stem'].values)
)
# Out:
# [2021-02-04 20:51:56,509] 	 fit vectorizers
# TfidfVectorizer(min_df=2, ngram_range=(1, 2))

# %%
"""
For both training and testing data.

find cosine distance between TF-IDF representation:
- query and product title
- query stemmed and product title stemmed
- query stemmed and product description stemmed

find ratio of matching words
- query stemmed and product title stemmed
"""
# Out:
# '\nfind cosine distance between TF-IDF representation:\n- query and product title\n- query stemmed and product title stemmed\n- query stemmed and product description stemmed\n\nfind ratio of matching words\n- query stemmed and product title stemmed\n'

# %%
# for train
logging.info('\t process train')
cosine_orig = []
cosine_stem = []
cosine_desc = []
set_stem = []
for i, row in train_df.iterrows():
    cosine_orig.append(calc_cosine_dist(row['query'], row['product_title'], tfv_orig))
    cosine_stem.append(calc_cosine_dist(row['query_stem'], row['title_stem'], tfv_stem))
    cosine_desc.append(calc_cosine_dist(row['query_stem'], row['desc_stem'], tfv_desc))
    set_stem.append(calc_set_intersection(row['query_stem'], row['title_stem']))
train_df['cosine_qt_orig'] = cosine_orig
train_df['cosine_qt_stem'] = cosine_stem
train_df['cosine_qd_stem'] = cosine_desc
train_df['set_qt_stem'] = set_stem
# Out:
# [2021-02-04 20:53:05,539] 	 process train

# %%
# for test
logging.info('\t process test')
cosine_orig = []
cosine_stem = []
cosine_desc = []
set_stem = []
for i, row in test_df.iterrows():
    cosine_orig.append(calc_cosine_dist(row['query'], row['product_title'], tfv_orig))
    cosine_stem.append(calc_cosine_dist(row['query_stem'], row['title_stem'], tfv_stem))
    cosine_desc.append(calc_cosine_dist(row['query_stem'], row['desc_stem'], tfv_desc))
    set_stem.append(calc_set_intersection(row['query_stem'], row['title_stem']))
test_df['cosine_qt_orig'] = cosine_orig
test_df['cosine_qt_stem'] = cosine_stem
test_df['cosine_qd_stem'] = cosine_desc
test_df['set_qt_stem'] = set_stem
# Out:
# [2021-02-04 20:55:46,171] 	 process test

# %%
train_df.iloc[:, 0:13].sample(10)
# Out:
#          id                       query  \
# 9046  29079      white plain dinner set
# 3519  11290            electric blanket
# 3036   9721    an extremely goofy movie
# 56      172                  duffle bag
# 1241   4030                  golf clubs
# 2986   9572             toddler sandals
# 1197   3883         rachel ray cookware
# 1606   5158            hair accessories
# 3826  12340                   levis 505
# 9889  31772  victorias secret lace gown
#
#                                           product_title  \
# 9046  50 PLAIN SOLID COLORS Dinner Hand towel NAPKIN...
# 3519  Serta Serta Luxe Plush Micro Fleece Electric B...
# 3036               AN EXTREMELY GOOFY MOVIE (VHS VIDEO)
# 56    Every Day Carry Tactical Large Heavy Duty Carr...
# 1241  WILSON Rookie Tour Junior Boys 5 Piece Complet...
# 2986     Toddler CROCS 'Cayman' Sandal, Size 2 M - Blue
# 1197  Rachael Ray Green Stoneware 4-pc. 10-oz. Bubbl...
# 1606  Crawford Corner Shop Black and White Houndstoo...
# 3826  Signature by Levi Strauss & Co. Men's Skinny J...
# 9889  Queen Satin Long Gown 7801X iCollection White ...
#
#                                     product_description  median_relevance  \
# 9046                                                                    1
# 3519  Patented, UL approved, Safe & Warm&trade, low ...                 4
# 3036                                                                    4
# 56    The Every Day Carry duffle bag is constructed ...                 4
# 1241  The Wilson Rookie Tour Junior Golf Set is grea...                 4
# 2986  Lightweight clogs are shaped from durable Cros...                 4
# 1197  Excite your dinner guests by serving your favo...                 2
# 1606                                                                    3
# 3826  These Signature by Levi Strauss & Co. men's sk...                 2
# 9889                                                                    2
#
#       relevance_variance                                          desc_stem  \
# 9046               0.000
# 3519               0.800  patented , ul approved , safe & warm & trade ,...
# 3036               0.471
# 56                 0.490  the every day carry duffle bag is constructed ...
# 1241               0.000  the wilson rookie tour junior golf set is grea...
# 2986               0.471  lightweight clog are shaped from durable crosl...
# 1197               0.745  excite your dinner guest by serving your favor...
# 1606               0.471
# 3826               0.800  these signature by levi strauss & co. men 's s...
# 9889               0.943
#
#                                              title_stem  \
# 9046  50 plain solid color dinner hand towel napkin ...
# 3519  serta serta luxe plush micro fleece electric b...
# 3036             an extremely goofy movie ( vhs video )
# 56    every day carry tactical large heavy duty carr...
# 1241  wilson rookie tour junior boy 5 piece complete...
# 2986     toddler crocs 'cayman ' sandal , size 2 m blue
# 1197  rachael ray green stoneware 4 pc. 10 oz. bubbl...
# 1606  crawford corner shop black and white houndstoo...
# 3826  signature by levi strauss & co. men 's skinny ...
# 9889  queen satin long gown 7801x icollection white ...
#
#                      query_stem  cosine_qt_orig  cosine_qt_stem  \
# 9046     white plain dinner set        0.819933        0.815318
# 3519           electric blanket        0.697337        0.697585
# 3036   an extremely goofy movie        0.282783        0.282818
# 56                   duffle bag        0.759637        0.761344
# 1241                  golf club        0.921274        0.698436
# 2986             toddler sandal        0.883858        0.747308
# 1197        rachel ray cookware        0.949513        0.945130
# 1606             hair accessory        0.894953        0.893090
# 3826                   levi 505        1.000000        0.894892
# 9889  victoria secret lace gown        0.928843        0.926444
#
#       cosine_qd_stem  set_qt_stem
# 9046        1.000000     0.500000
# 3519        0.898917     1.000000
# 3036        1.000000     1.000000
# 56          0.893725     1.000000
# 1241        0.972894     1.000000
# 2986        1.000000     1.000000
# 1197        0.986241     0.333333
# 1606        1.000000     0.500000
# 3826        0.939795     0.500000
# 9889        1.000000     0.250000

# %% [markdown]
# # w2v part

# %%
"""
Find distance between the average word2vec vectors.
"""

# %%
def calc_w2v_sim(row):
    '''
    Calc w2v similarities and diff of centers of query\title
    '''
    a2 = [x for x in row['query_stem'].lower().split() if x in embedder.vocab]
    b2 = [x for x in row['title_stem'].lower().split() if x in embedder.vocab]
    if len(a2)>0 and len(b2)>0:
        w2v_sim = embedder.n_similarity(a2, b2)
    else:
        return((-1, -1, np.zeros(300)))
    
    vectorA = np.zeros(300)
    for w in a2:
        vectorA += embedder[w]
    vectorA /= len(a2)

    vectorB = np.zeros(300)
    for w in b2:
        vectorB += embedder[w]
    vectorB /= len(b2)

    vector_diff = (vectorA - vectorB)

    w2v_vdiff_dist = np.sqrt(np.sum(vector_diff**2))
    return (w2v_sim, w2v_vdiff_dist, vector_diff)
# Out:
# [2021-02-05 09:59:09,387] 	 load pretrained model from ../tools-w2v/GoogleNews-vectors-negative300.bin
# [2021-02-05 09:59:09,388] loading projection weights from ../tools-w2v/GoogleNews-vectors-negative300.bin
# [2021-02-05 09:59:47,403] loaded (3000000, 300) matrix from ../tools-w2v/GoogleNews-vectors-negative300.bin

# %%
logging.info('\t load pretrained model from {}'.format(cfg.path_w2v_pretrained_model))
embedder = KeyedVectors.load_word2vec_format(cfg.path_w2v_pretrained_model, binary=True)
# Out:
# [2021-02-05 19:42:15,069] 	 load pretrained model from ../tools-w2v/GoogleNews-vectors-negative300.bin
# [2021-02-05 19:42:15,073] loading projection weights from ../tools-w2v/GoogleNews-vectors-negative300.bin
# [2021-02-05 19:43:05,672] loaded (3000000, 300) matrix from ../tools-w2v/GoogleNews-vectors-negative300.bin

# %%
# for train
logging.info('\t process train')
X_w2v = []
sim_list = []
dist_list = []
for i,row in train_df.iterrows():
    sim, dist, vdiff = calc_w2v_sim(row)
    X_w2v.append(vdiff)
    sim_list.append(sim)
    dist_list.append(dist)
X_w2v_tr = np.array(X_w2v)
train_df['w2v_sim'] = np.array(sim_list)
train_df['w2v_dist'] = np.array(dist_list)
# Out:
# [2021-02-05 19:43:15,972] 	 process train

# %%
# for test
logging.info('\t process test')
X_w2v = []
sim_list = []
dist_list = []
for i,row in test_df.iterrows():
    sim, dist, vdiff = calc_w2v_sim(row)
    X_w2v.append(vdiff)
    sim_list.append(sim)
    dist_list.append(dist)
X_w2v_te = np.array(X_w2v)
test_df['w2v_sim'] = np.array(sim_list)
test_df['w2v_dist'] = np.array(dist_list)
# Out:
# [2021-02-05 19:43:21,497] 	 process test

# %%
X_w2v_tr[1][0:20]
# Out:
# array([ 0.05483704,  0.03566895,  0.01350098, -0.03406982,  0.00502218,
#        -0.04147949,  0.01893565, -0.04858398, -0.07416992,  0.0942805 ,
#         0.05486654, -0.10199382,  0.0446106 , -0.02469076,  0.09288534,
#        -0.04185384,  0.04448751,  0.02110596, -0.02271678, -0.10723877])

# %%
train_df.iloc[:, [1,2,3,4,5,6,7,8,9, 13,14]].sample(10)
# Out:
#                              query  \
# 3454  teenage mutant ninja turtles
# 6091                   table clock
# 7511            watch women fossil
# 92             san francisco 49ers
# 7473             cast iron skillet
# 3751                  pencil skirt
# 1480                   nike womens
# 1430            memory foam pillow
# 1968          coffee for nespresso
# 6755                  oakley radar
#
#                                           product_title  \
# 3454  Teenage Mutant Ninja Turtles Newborn Boys' Bod...
# 6091                       Cas sem Aluminum Clock Table
# 7511  Fossil Women's Sculptor Watch Quartz Mineral C...
# 92    San Francisco 49ers Official NFL Infant One Si...
# 7473  Griswold #6 Chrome Cast Iron Skillet Pn#699 Sm...
# 3751         Women's Jacquard Pencil Skirt Black Merona
# 1480  Womens Nike Dri-Fit Epic Run Capris - Hot Pink...
# 1430  Dough Supportive Low Loft Firm Memory Foam Pillow
# 1968  My-Cap Capsule Holder for Nespresso VirtuoLine...
# 6755  Oakley Radar EV Pitch with Grey Ink Frame and ...
#
#                                     product_description  median_relevance  \
# 3454  Teenage Mutant Ninja Turtles Newborn Boys' Bod...                 2
# 6091  This riveted, vintage aluminum Cas sem clock t...                 3
# 7511  Fossil Women's Sculptor Stainless steel case, ...                 4
# 92    Keep your baby warm and dry in this hooded tow...                 4
# 7473                                                                    4
# 3751                                                                    4
# 1480  Don't let your running clothes slow you down. ...                 4
# 1430  The Dough pillow is constructed with Memory Fo...                 4
# 1968                                                                    2
# 6755  Oakley items are available for US sales only. ...                 4
#
#       relevance_variance                                          desc_stem  \
# 3454               0.943  teenage mutant ninja turtle newborn boy ' body...
# 6091               1.166  this riveted , vintage aluminum ca sem clock t...
# 7511               0.000  fossil woman 's sculptor stainless steel case ...
# 92                 0.471  keep your baby warm and dry in this hooded tow...
# 7473               0.000
# 3751               0.800
# 1480               0.471  do n't let your running clothes slow you down....
# 1430               0.000  the dough pillow is constructed with memory fo...
# 1968               0.000
# 6755               0.000  oakley item are available for u sale only. we ...
#
#                                              title_stem  \
# 3454  teenage mutant ninja turtle newborn boy ' body...
# 6091                        ca sem aluminum clock table
# 7511  fossil woman 's sculptor watch quartz mineral ...
# 92    san francisco 49ers official nfl infant one si...
# 7473  griswold # 6 chrome cast iron skillet pn # 699...
# 3751        woman 's jacquard pencil skirt black merona
# 1480  woman nike dri fit epic run capri hot pink hot...
# 1430  dough supportive low loft firm memory foam pillow
# 1968  my cap capsule holder for nespresso virtuoline...
# 6755  oakley radar ev pitch with grey ink frame and ...
#
#                        query_stem  cosine_qt_orig   w2v_sim  w2v_dist
# 3454  teenage mutant ninja turtle        0.585270  0.822669  1.225705
# 6091                  table clock        0.672844  0.628914  1.744994
# 7511           watch woman fossil        0.724925  0.713991  1.386204
# 92            san francisco 49ers        0.537895  0.460351  1.841848
# 7473            cast iron skillet        0.519278  0.698564  1.825989
# 3751                 pencil skirt        0.486526  0.816115  1.329119
# 1480                   nike woman        0.857100  0.560681  1.798385
# 1430           memory foam pillow        0.638711  0.780288  1.457710
# 1968         coffee for nespresso        0.750804  0.200269  2.155609
# 6755                 oakley radar        0.699900  0.417584  2.995795

# %%
logging.info('\t dump w2v-features')
pickle.dump((X_w2v_tr, X_w2v_te), open(cfg.path_processed + 'X_w2v.pickled', 'wb'), protocol=2)
# Out:
# [2021-02-05 19:43:28,787] 	 dump w2v-features

# %% [markdown]
# # tSNE features

# %%
"""
Levenshtein distance
for title
for title-query
for description
"""

# %%
logging.info('tSNE part')
logging.info('\t [1\3] process title')
vect = TfidfVectorizer(ngram_range=(1,2), min_df=3)
X_tf = vect.fit_transform(list(train_df['title_stem'].values) + list(test_df['title_stem'].values))
svd = TruncatedSVD(n_components=200)
X_svd = svd.fit_transform(X_tf)
X_scaled = StandardScaler().fit_transform(X_svd)
#X_tsne = bh_sne(X_scaled)
X_tsne = TSNE(method='barnes_hut').fit_transform(X_scaled)

train_df['tsne_title_1'] = X_tsne[:len(train_df), 0]
train_df['tsne_title_2'] = X_tsne[:len(train_df), 1]
test_df[ 'tsne_title_1'] = X_tsne[len(train_df):, 0]
test_df[ 'tsne_title_2'] = X_tsne[len(train_df):, 1]
# Out:
# [2021-02-05 19:43:29,468] tSNE part
# [2021-02-05 19:43:29,470] 	 [1] process title

# %%
train_df.iloc[:, [1,2,3,4,5,6,7,8,9, 15,16]].sample(10)
# Out:
#                        query  \
# 131               aqua shoes
# 162           wreck it ralph
# 265          fuji bike shirt
# 7789   rubbermaid turntables
# 7040           glitter vials
# 1820       candle chandelier
# 2993              sports bra
# 8963  multiple phone charger
# 6972         polaroid camera
# 5733         polaroid camera
#
#                                           product_title  \
# 131        Women's Skechers GOrun Ultra 2 Hot Pink/Aqua
# 162            Girl's Wreck-It Ralph Time Teacher Watch
# 265   Asics 2014 Men's Fuji Long Sleeve 1/2 Zip Runn...
# 7789        Rubbermaid FG1A7109 Twin Turntable, No Skid
# 7040  ***FAST TRACK*** Elmer's 3D Glitter Glue Paint...
# 1820  CHIC DAZZLING SHABBY DISTRESS CHIC BEADED Chan...
# 2993  Champion Double Dry Seamless Racerback Sports Bra
# 8963  Clear Gear SW-004 Wally - Dual USB Plush DC Wa...
# 6972  Polaroid Id610-blu 14.0 Megapixel All-weather ...
# 5733  Unused Polaroid SX-70, 680 Or 690 Instant Came...
#
#                                     product_description  median_relevance  \
# 131   The acclaimed Skechers GOrun Ultra gets even b...                 2
# 162                                                                     4
# 265   When you decide to brave less than ideal weath...                 2
# 7789                                                                    4
# 7040  Elmer's 3D Glitter Glue Paint Pens add a new d...                 2
# 1820                                                                    4
# 2993  This updated sports bra is seamless all over f...                 4
# 8963  FeaturesThe Schatzii WALLY - Dual USB DC Wall ...                 2
# 6972  All-weather digital camcorder Fog proof, sand ...                 2
# 5733                                                                    2
#
#       relevance_variance                                          desc_stem  \
# 131                0.943  the acclaimed skechers gorun ultra get even be...
# 162                0.000
# 265                0.943  when you decide to brave le than ideal weather...
# 7789               0.000
# 7040               0.471  elmer 's 3d glitter glue paint pen add a new d...
# 1820               0.000
# 2993               0.000  this updated sport bra is seamless all over fo...
# 8963               0.800  featuresthe schatzii wally dual usb dc wall ch...
# 6972               0.943  all weather digital camcorder fog proof , sand...
# 5733               0.000
#
#                                              title_stem  \
# 131       woman 's skechers gorun ultra 2 hot pink aqua
# 162           girl 's wreck it ralph time teacher watch
# 265   asics 2014 men 's fuji long sleeve 1 2 zip run...
# 7789       rubbermaid fg1a7109 twin turntable , no skid
# 7040  ***fast track*** elmer 's 3d glitter glue pain...
# 1820  chic dazzling shabby distress chic beaded chan...
# 2993   champion double dry seamless racerback sport bra
# 8963  clear gear sw 004 wally dual usb plush dc wall...
# 6972  polaroid id610 blu 14.0 megapixel all weather ...
# 5733  unused polaroid sx 70 , 680 or 690 instant cam...
#
#                   query_stem  cosine_qt_orig  tsne_title_1  tsne_title_2
# 131                aqua shoe        0.855906     39.220203     33.255306
# 162           wreck it ralph        0.508000    -15.271293    -81.284805
# 265          fuji bike shirt        0.899232     12.687432     44.267620
# 7789    rubbermaid turntable        0.873322     10.550785    -29.277102
# 7040            glitter vial        0.871965      1.072130      1.404547
# 1820       candle chandelier        0.806710    -20.190968    -31.843819
# 2993               sport bra        0.625713     26.961023     30.076130
# 8963  multiple phone charger        0.949456      8.344467    -36.728703
# 6972         polaroid camera        0.882835      3.093921     -7.943844
# 5733         polaroid camera        0.822320      2.883445    -31.514324

# %%
logging.info('\t [2\3] process title-query')
vect = TfidfVectorizer(ngram_range=(1,2), min_df=3)
X_title = vect.fit_transform(list(train_df['title_stem'].values) + list(test_df['title_stem'].values))
X_query = vect.fit_transform(list(train_df['query_stem'].values) + list(test_df['query_stem'].values))
X_tf = sp.hstack([X_title, X_query]).tocsr()
svd = TruncatedSVD(n_components=200)
X_svd = svd.fit_transform(X_tf)
X_scaled = StandardScaler().fit_transform(X_svd)
#X_tsne = bh_sne(X_scaled)
X_tsne = TSNE(method='barnes_hut').fit_transform(X_scaled)

train_df['tsne_qt_1'] = X_tsne[:len(train_df), 0]
train_df['tsne_qt_2'] = X_tsne[:len(train_df), 1]
test_df[ 'tsne_qt_1'] = X_tsne[len(train_df):, 0]
test_df[ 'tsne_qt_2'] = X_tsne[len(train_df):, 1]
# Out:
# [2021-02-05 19:55:59,733] 	 [2] process title-query

# %%
train_df.iloc[:, [1,2,3,4,5,6,7,8,9, 17,18]].sample(10)
# Out:
#                      query                                      product_title  \
# 4866        steel necklace  Gold Plated Stainless Steel Necklace With Pendant
# 1252                 levis       511 Slim Fit Line 8 Pants - Graphite Melange
# 6591       silver necklace         Italian Sterling Silver Box Chain Necklace
# 2435       patio umbrellas  Fiberbuilt Umbrellas 9 ft. Patio Umbrella in F...
# 5331           wii gamepad  PDP - NERF Armor Case for Nintendo Wii U GameP...
# 6613      electric blanket  Perfect Fit Microfleece Electric Blanket Beige...
# 4041      electric griddle                          Oster DuraCeramic Griddle
# 1983            duffle bag  CalPak Silver Lake Solid 22-inch Carry-on Duff...
# 9170    mac book air cover                NOOK Color Insutriell Cover - Black
# 7128  coffee for nespresso  30 Pack Mixpresso Nespresso Compatible Coffee ...
#
#                                     product_description  median_relevance  \
# 4866  ELYA's signature hangs from this cable chain n...                 4
# 1252  The Line 8 collection is a carefully designed ...                 2
# 6591  Italian Sterling Silver Box Chain Necklace. Fi...                 4
# 2435  About Fiberbuilt Umbrellas FiberBuilt Umbrella...                 4
# 5331  Protect your Wii U GamePad from accidental bum...                 2
# 6613                                                                    4
# 4041                                                                    4
# 1983  This large carry-on 22-inch duffel bag feature...                 4
# 9170  Protect your Nook Color or Nook Tablet with th...                 2
# 7128  Several rich flavors made with coffee beans se...                 3
#
#       relevance_variance                                          desc_stem  \
# 4866               0.471  elya 's signature hang from this cable chain n...
# 1252               0.632  the line 8 collection is a carefully designed ...
# 6591               0.000  italian sterling silver box chain necklace. fi...
# 2435               0.000  about fiberbuilt umbrella fiberbuilt umbrella ...
# 5331               0.471  protect your wii u gamepad from accidental bum...
# 6613               0.000
# 4041               0.471
# 1983               0.000  this large carry on 22 inch duffel bag feature...
# 9170               0.471  protect your nook color or nook tablet with th...
# 7128               0.471  several rich flavor made with coffee bean sele...
#
#                                              title_stem            query_stem  \
# 4866  gold plated stainless steel necklace with pendant        steel necklace
# 1252          511 slim fit line 8 pant graphite melange                  levi
# 6591         italian sterling silver box chain necklace       silver necklace
# 2435  fiberbuilt umbrella 9 ft. patio umbrella in fo...        patio umbrella
# 5331  pdp nerf armor case for nintendo wii u gamepad...           wii gamepad
# 6613  perfect fit microfleece electric blanket beige...      electric blanket
# 4041                          oster duraceramic griddle      electric griddle
# 1983  calpak silver lake solid 22 inch carry on duff...            duffle bag
# 9170                  nook color insutriell cover black    mac book air cover
# 7128  30 pack mixpresso nespresso compatible coffee ...  coffee for nespresso
#
#       cosine_qt_orig  tsne_qt_1  tsne_qt_2
# 4866        0.629464 -27.431309  45.992661
# 1252        1.000000 -14.331005  73.055389
# 6591        0.769718  30.543852  -2.663028
# 2435        0.803812  17.178013 -14.857862
# 5331        0.649157 -36.174004 -28.762239
# 6613        0.604955  45.447403 -61.349617
# 4041        0.774674 -38.001877 -57.483238
# 1983        0.929620  26.534119 -72.668640
# 9170        0.905746 -27.272736 -59.423183
# 7128        0.856481  48.428074   0.174882

# %%
logging.info('\t [3\3] process description')
vect = TfidfVectorizer(ngram_range=(1,2), min_df=3)
X_desc = vect.fit_transform(list(train_df['desc_stem'].values) + list(test_df['desc_stem'].values))
X_tf = X_desc
svd = TruncatedSVD(n_components=200)
X_svd = svd.fit_transform(X_tf)
X_scaled = StandardScaler().fit_transform(X_svd)
#X_tsne = bh_sne(X_scaled)
X_tsne = TSNE(method='barnes_hut').fit_transform(X_scaled)

train_df['tsne_desc_1'] = X_tsne[:len(train_df), 0]
train_df['tsne_desc_2'] = X_tsne[:len(train_df), 1]
test_df[ 'tsne_desc_1'] = X_tsne[len(train_df):, 0]
test_df[ 'tsne_desc_2'] = X_tsne[len(train_df):, 1]
# Out:
# [2021-02-05 20:02:40,118] 	 [3] process description

# %%
train_df.iloc[:, [1,2,3,4,5,6,7,8,9, 19,20]].sample(10)
# Out:
#                          query  \
# 4105  screen protector samsung
# 7460              road bicycle
# 8842          drawer organizer
# 9455       speck iphone 5 case
# 5192                    barbie
# 4990              dress shirts
# 5801        converse high tops
# 8631              cocoa butter
# 6812              road bicycle
# 7936            candle lantern
#
#                                           product_title  \
# 4105     Screen Protector for Samsung Galaxy Note N7000
# 7460  Takara Men's 700C 1-Speed Sugiyama Takara Road...
# 8842                Safco Drawer Organizer, Mesh, Black
# 9455  Speck CandyShell Grip 2-Layers Hard Shell Gami...
# 5192                     Barbie in the Nutcracker (DVD)
# 4990  Coogi Luxe Men's Light Purple Button-down Dres...
# 5801  Converse CT Ox Youth Girls Size 3 Bronze Texti...
# 8631  Badger Cocoa Butter Lip Balm, Vanilla Bean, .2...
# 6812  Schwinn Men's Drop Bar Road Volare 1300 Road Bike
# 7936            Threshold Large Lantern with LED Candle
#
#                                     product_description  median_relevance  \
# 4105  This is a screen protector for Samsung© Galaxy...                 4
# 7460                                                                    4
# 8842  Low-profile organizer with a variety of bin si...                 4
# 9455                                                                    4
# 5192  ITEM#: 13041370\nAmerica's favorite pint-sized...                 1
# 4990  Crafted with the finest materials and unparall...                 4
# 5801  The Converse brand of athletic shoes, which no...                 2
# 8631                                                                    2
# 6812                                                                    4
# 7936                                                                    4
#
#       relevance_variance                                          desc_stem  \
# 4105               0.000  this is a screen protector for samsung© galaxy...
# 7460               0.000
# 8842               0.000  low profile organizer with a variety of bin si...
# 9455               0.471
# 5192               0.943  item # : 13041370 america 's favorite pint siz...
# 4990               0.433  crafted with the finest material and unparalle...
# 5801               0.471  the converse brand of athletic shoe , which no...
# 8631               0.471
# 6812               0.471
# 7936               0.471
#
#                                              title_stem  \
# 4105     screen protector for samsung galaxy note n7000
# 7460  takara men 's 700c 1 speed sugiyama takara roa...
# 8842              safco drawer organizer , mesh , black
# 9455  speck candyshell grip 2 layer hard shell gamin...
# 5192                   barbie in the nutcracker ( dvd )
# 4990  coogi luxe men 's light purple button down dre...
# 5801  converse ct ox youth girl size 3 bronze textil...
# 8631  badger cocoa butter lip balm , vanilla bean , ...
# 6812  schwinn men 's drop bar road volare 1300 road ...
# 7936            threshold large lantern with led candle
#
#                     query_stem  cosine_qt_orig  tsne_desc_1  tsne_desc_2
# 4105  screen protector samsung        0.479583    46.491837    21.672194
# 7460              road bicycle        0.881682    -5.200672     0.219500
# 8842          drawer organizer        0.558649     9.877446   -48.047688
# 9455       speck iphone 5 case        0.820747     7.847014     9.841880
# 5192                    barbie        0.691583   -49.469311   -16.825737
# 4990               dress shirt        0.937467   -42.411716   -11.670886
# 5801         converse high top        0.941901   -24.418301    40.196121
# 8631              cocoa butter        0.665430     2.985541    14.526398
# 6812              road bicycle        0.725910    -6.019669    -6.949962
# 7936            candle lantern        0.740120    -6.924657     6.732132

# %%
logging.info('\t dump results')
train_df.to_pickle(cfg.path_processed + 'train_df')
test_df.to_pickle( cfg.path_processed + 'test_df')
# Out:
# [2021-02-05 20:16:02,529] 	 dump results

# %% [markdown]
# # X_additional

# %%
logging.info("Dump additional features")
feat_list = [
    u'w2v_sim',
    u'w2v_dist',
    u'tsne_title_1', 
    u'tsne_title_2', 
    u'tsne_qt_1',
    u'tsne_qt_2',
    u'cosine_qt_orig', 
    u'cosine_qt_stem', 
    u'cosine_qd_stem',
    u'set_qt_stem'
]
X_additional_tr = train_df[feat_list].values
X_additional_te = test_df[feat_list].values
# Out:
# [2021-02-05 20:16:02,759] Dump additional features

# %%
np.savetxt(cfg.path_processed + 'X_additional_tr.txt', X_additional_tr)
np.savetxt(cfg.path_processed + 'X_additional_te.txt', X_additional_te)
